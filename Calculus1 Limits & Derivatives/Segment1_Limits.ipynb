# %% [markdown]
# *Segment 1: Limits*
# *   What Calculus Is
# *   A Brief History of Calculus
# *   The Method of Exhaustion
# *   Calculating Limits

# %% [markdown]
# ---
# ---
# ## **Segment 1: Limits**
# ---

# %% [markdown]
# ### **1. The Calculus of Infinitesimals**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 1000)
# start, finish, n points
x
# Out:
# array([-10.        ,  -9.97997998,  -9.95995996,  -9.93993994,
#         -9.91991992,  -9.8998999 ,  -9.87987988,  -9.85985986,
#         -9.83983984,  -9.81981982,  -9.7997998 ,  -9.77977978,
#         -9.75975976,  -9.73973974,  -9.71971972,  -9.6996997 ,
#         -9.67967968,  -9.65965966,  -9.63963964,  -9.61961962,
#         -9.5995996 ,  -9.57957958,  -9.55955956,  -9.53953954,
#         -9.51951952,  -9.4994995 ,  -9.47947948,  -9.45945946,
#         -9.43943944,  -9.41941942,  -9.3993994 ,  -9.37937938,
#         -9.35935936,  -9.33933934,  -9.31931932,  -9.2992993 ,
#         -9.27927928,  -9.25925926,  -9.23923924,  -9.21921922,
#         -9.1991992 ,  -9.17917918,  -9.15915916,  -9.13913914,
#         -9.11911912,  -9.0990991 ,  -9.07907908,  -9.05905906,
#         -9.03903904,  -9.01901902,  -8.998999  ,  -8.97897898,
#         -8.95895896,  -8.93893894,  -8.91891892,  -8.8988989 ,
#         -8.87887888,  -8.85885886,  -8.83883884,  -8.81881882,
# ...

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots(figsize=(10, 6))
_ = ax.plot(x,y)

# %% [markdown]
# * There are no straight lines on the curve.
# * If we zoom in infinitely close, however, we observe curves that approach lines.
# * This enables us to find a slope m
#  (tangent) anywhere on the curve, including to identify where m = 0
# :

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0, 2])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %% [markdown]
# ---
# ### **2. Limits**

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-5, 10)
plt.ylim(-10, 80)
plt.axvline(x=5, color='purple', linestyle='--')
plt.axhline(y=37, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 1} \frac{x^2 - 1}{x - 1}$$

# %%
def func(x):
    y = (x**2 - 1)/(x - 1)
    return y

# %%
func(2)
# Out:
# 3.0

# %%
func(0.9)
# Out:
# 1.9

# %%
func(1.1)
# Out:
# 2.1

# %%
func(1.001)
# Out:
# 2.0009999999999177

# %%
y = func(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.axvline(x=1, color='purple', linestyle='--')
plt.axhline(y=2, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 0} \frac{\text{sin } x}{x}$$

# %%
def sin_func(x):
    y = np.sin(x)/x
    return y

# %%
sin_func(0.1)
# Out:
# 0.9983341664682815

# %%
sin_func(0.001)
# Out:
# 0.9999998333333416

# %%
sin_func(-0.1)
# Out:
# 0.9983341664682815

# %%
sin_func(-0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_func(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-1, 2)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$ \lim_{x \to \infty} \frac{25}{x} $$

# %%
def inf_func(x):
    y = 25/x
    return y

# %%
inf_func(1e3)
# Out:
# 0.025

# %%
inf_func(1e6)
# Out:
# 2.5e-05

# %%
y = inf_func(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
_ = ax.plot(x, y)

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y = inf_func(left_x)
right_y = inf_func(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
ax.plot(left_x, left_y, c='C0')
_ = ax.plot(right_x, right_y, c='C0')

# %% [markdown]
# ---
# ### **Exercises:**
#
#
# 1. $$ \lim_{x \to 0} \frac{x^2-1}{x-1} $$

# %%
def func1(x):
    y = (x**2 - 1)/(x - 1)
    return y

# %%
y1 = func1(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y1)

# %% [markdown]
# 2. $$ \lim_{x \to -5} \frac{x^2-25}{x+5} $$

# %%
def func2(x):
    y = (x**2 - 25)/(x + 5)
    return y

# %%
y2 = func2(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-20, 10)
plt.axvline(x=-5, color='purple', linestyle='--')
plt.axhline(y=-10, color='purple', linestyle='--')
_ = ax.plot(x,y2)

# %% [markdown]
# 3. $$ \lim_{x \to 4} \frac{x^2 -2x -8}{x-4} $$

# %%
def func3(x):
    y = (x**2 - 2*x - 8)/(x - 4)
    return y

# %%
y3 = func3(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.axvline(x=4, color='purple', linestyle='--')
plt.axhline(y=6, color='purple', linestyle='--')
_ = ax.plot(x,y3)

# %% [markdown]
# 4. $$ \lim_{x \to -\infty} \frac{25}{x} $$

# %%
def func4(x):
  y = 25/x
  return y

# %%
y4 = func4(x)

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y4 = func4(left_x)
right_y4 = func4(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
plt.axvline(x=-np.inf, color='purple', linestyle='--')
plt.axhline(y=0, color='purple', linestyle='--')
ax.plot(left_x, left_y4,c='C0')
_ = ax.plot(right_x, right_y4, c='C0')

# %% [markdown]
# 5. $$ \lim_{x \to 0} \frac{25}{x} $$

# %%
def func5(x):
  y = 25/x
  return y

# %%
y5 = func5(x)

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y5 = func5(left_x)
right_y5 = func5(right_x)

# %%
fig, ax= plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=0, color='purple', linestyle='--')
ax.plot(left_x, left_y5,c='C0')
_ = ax.plot(right_x, right_y5, c='C0')
